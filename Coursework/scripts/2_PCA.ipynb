# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.decomposition import TruncatedSVD,PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import train_test_split 
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import RocCurveDisplay,roc_auc_score
from sklearn.model_selection import GridSearchCV

from sklearn.feature_extraction.text import TfidfTransformer

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.svm import SVC

# %%
path = "/content/drive/MyDrive/Materias/MLEA_M/Coursework/"

df_train = pd.read_csv(path + "spam_dataset.csv")
df_test = pd.read_csv(path + "spam_dataset_test.csv")

# %%
x_test=df_test.drop("email_id",axis=1)

# %%
df_train2 = df_train.drop('email_id', axis=1)
x = df_train2.drop('spam',axis=1)
y = df_train2[['spam']]
x_train, x_val, y_train, y_val = train_test_split(df_train2.drop('spam',axis=1), df_train2[['spam']], test_size=0.3, random_state=12)

# %%
columns_all= list(df_train.drop(['email_id','spam'],axis=1))
columns_freq = list(filter(lambda x: 'word_freq' in x, list(df_train.drop(['email_id','spam'], axis=1).columns)))
columns_no_freq = list(filter(lambda x: 'word_freq' not in x, list(df_train.drop(['email_id','spam'], axis=1).columns)))

# %%
y_train.shape, x_test.shape
# Out:
# ((2254, 1), (1381, 57))

# %% [markdown]
# # PCA

# %%
ct = ColumnTransformer([("scaler", StandardScaler(), columns_all),
                        ('pca',TruncatedSVD(n_iter=7, random_state=42),columns_freq),
                        ('pca2',PCA(n_components=3, random_state=42),columns_no_freq[0:6]),
                        ('pca3',PCA(n_components=2, random_state=42),columns_no_freq[6:])])

# %% [markdown]
# ## LR

# %%
clf = Pipeline(
    steps=[("pre", ct),("clf", LogisticRegression(max_iter=500))]
)
params={'pre__pca__n_components':[25,30,40],
        'clf__C':[0.01,0.1,1,10,80,100,300],
        'clf__penalty':['l1', 'l2'],
        'clf__class_weight':['balanced'],
        'clf__solver': ['liblinear'],
        }

GS = GridSearchCV(clf,param_grid = params, scoring = ['roc_auc','balanced_accuracy'], n_jobs=-1, cv=5, refit=False)

# %%
GS.fit(x_train,y_train)
df_results = pd.DataFrame(GS.cv_results_)
df_results[['params','mean_test_roc_auc', 'std_test_roc_auc','mean_test_balanced_accuracy','std_test_balanced_accuracy']].sort_values(by='mean_test_roc_auc',ascending=False).head(10)
# Out:
#                                                params  mean_test_roc_auc  \
# 17  {'clf__C': 1, 'clf__class_weight': 'balanced',...           0.968533
# 15  {'clf__C': 1, 'clf__class_weight': 'balanced',...           0.968406
# 16  {'clf__C': 1, 'clf__class_weight': 'balanced',...           0.968398
# 12  {'clf__C': 1, 'clf__class_weight': 'balanced',...           0.968350
# 13  {'clf__C': 1, 'clf__class_weight': 'balanced',...           0.968309
# 14  {'clf__C': 1, 'clf__class_weight': 'balanced',...           0.968136
# 22  {'clf__C': 10, 'clf__class_weight': 'balanced'...           0.967090
# 11  {'clf__C': 0.1, 'clf__class_weight': 'balanced...           0.967049
# 10  {'clf__C': 0.1, 'clf__class_weight': 'balanced...           0.966971
# 9   {'clf__C': 0.1, 'clf__class_weight': 'balanced...           0.966950
#
#     std_test_roc_auc  mean_test_balanced_accuracy  std_test_balanced_accuracy
# 17          0.005543                     0.920046                    0.011068
# 15          0.005782                     0.920223                    0.010874
# 16          0.005751                     0.920046                    0.011068
# 12          0.005471                     0.920987                    0.009162
# 13          0.005503                     0.920987                    0.009162
# 14          0.005539                     0.920796                    0.009789
# 22          0.006458                     0.917294                    0.012084
# 11          0.004223                     0.916332                    0.005510
# 10          0.004236                     0.916699                    0.005641
# 9           0.004191                     0.916699                    0.005641

# %% [markdown]
# ## SVM

# %%
clf = Pipeline(
    steps=[("pre", ct),("clf", SVC())]
)
params={'pre__pca__n_components':[25,30,40],
        'clf__C':[0.1,1,5,10,20,50,80],
        'clf__kernel':['rbf'],
        'clf__class_weight':['balanced'],
        'clf__gamma': ['auto','scale'],
        }
GS = GridSearchCV(clf,param_grid = params, scoring = ['roc_auc','balanced_accuracy'], n_jobs=-1, cv=5, refit=False)

# %%
GS.fit(x_train,y_train)
df_results = pd.DataFrame(GS.cv_results_)
df_results[['params','mean_test_roc_auc', 'std_test_roc_auc','mean_test_balanced_accuracy','std_test_balanced_accuracy']].sort_values(by='mean_test_roc_auc',ascending=False).head(10)
# Out:
#                                                params  mean_test_roc_auc  \
# 41  {'clf__C': 80, 'clf__class_weight': 'balanced'...           0.922036
# 40  {'clf__C': 80, 'clf__class_weight': 'balanced'...           0.921897
# 39  {'clf__C': 80, 'clf__class_weight': 'balanced'...           0.921720
# 14  {'clf__C': 5, 'clf__class_weight': 'balanced',...           0.909762
# 20  {'clf__C': 10, 'clf__class_weight': 'balanced'...           0.908303
# 13  {'clf__C': 5, 'clf__class_weight': 'balanced',...           0.908274
# 12  {'clf__C': 5, 'clf__class_weight': 'balanced',...           0.907932
# 35  {'clf__C': 50, 'clf__class_weight': 'balanced'...           0.906602
# 34  {'clf__C': 50, 'clf__class_weight': 'balanced'...           0.906602
# 33  {'clf__C': 50, 'clf__class_weight': 'balanced'...           0.906368
#
#     std_test_roc_auc  mean_test_balanced_accuracy  std_test_balanced_accuracy
# 41          0.010698                     0.848081                    0.007423
# 40          0.010810                     0.848081                    0.007423
# 39          0.010864                     0.848268                    0.007237
# 14          0.009632                     0.832969                    0.015681
# 20          0.010303                     0.832412                    0.014629
# 13          0.010054                     0.832409                    0.014707
# 12          0.010309                     0.832222                    0.013609
# 35          0.011436                     0.833500                    0.007642
# 34          0.011354                     0.833500                    0.007642
# 33          0.011394                     0.832573                    0.008590

# %% [markdown]
# ## RF

# %%
clf = Pipeline(
    steps=[("pre", ct),("clf", RandomForestClassifier())]
)

params={'pre__pca__n_components':[25,30,40],
        'clf__n_estimators':[50,100,150,200,250],
        'clf__class_weight':['balanced'],
        'clf__max_features': ['sqrt','log2'],
        'clf__min_samples_split': [3,5,8,10]
        }
GS = GridSearchCV(clf,param_grid = params, scoring = ['roc_auc','balanced_accuracy'], n_jobs=-1, cv=5, refit=False)

# %%
GS.fit(x_train,y_train)
df_results = pd.DataFrame(GS.cv_results_)
df_results[['params','mean_test_roc_auc', 'std_test_roc_auc','mean_test_balanced_accuracy','std_test_balanced_accuracy']].sort_values(by='mean_test_roc_auc',ascending=False).head(10)
# Out:
#                                                 params  mean_test_roc_auc  \
# 4    {'clf__class_weight': 'balanced', 'clf__max_fe...           0.983071
# 73   {'clf__class_weight': 'balanced', 'clf__max_fe...           0.982721
# 67   {'clf__class_weight': 'balanced', 'clf__max_fe...           0.982666
# 85   {'clf__class_weight': 'balanced', 'clf__max_fe...           0.982592
# 66   {'clf__class_weight': 'balanced', 'clf__max_fe...           0.982496
# 87   {'clf__class_weight': 'balanced', 'clf__max_fe...           0.982465
# 89   {'clf__class_weight': 'balanced', 'clf__max_fe...           0.982391
# 70   {'clf__class_weight': 'balanced', 'clf__max_fe...           0.982341
# 112  {'clf__class_weight': 'balanced', 'clf__max_fe...           0.982325
# 72   {'clf__class_weight': 'balanced', 'clf__max_fe...           0.982226
#
#      std_test_roc_auc  mean_test_balanced_accuracy  std_test_balanced_accuracy
# 4            0.001861                     0.941063                    0.007250
# 73           0.001913                     0.938070                    0.006300
# 67           0.002094                     0.939738                    0.006587
# 85           0.002887                     0.939577                    0.010425
# 66           0.002245                     0.938072                    0.008664
# 87           0.001909                     0.938069                    0.007762
# 89           0.002217                     0.937718                    0.009962
# 70           0.002047                     0.937704                    0.007992
# 112          0.002028                     0.936982                    0.005927
# 72           0.002024                     0.939934                    0.009510

# %%
clf.set_params(**	{'clf__class_weight': 'balanced', 'clf__max_features': 'log2', 'clf__min_samples_split': 3, 'clf__n_estimators': 250, 'pre__pca__n_components': 40})
clf.fit(x_train,y_train)

model_results = pd.DataFrame({"email_id": df_test.email_id, "predicted" : clf.predict_proba(x_test)[:,1]})
# model_results.to_csv("rf_standard_tifdf_pca_full.csv", index=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/pipeline.py:394: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)

# %% [markdown]
# ## GBM

# %%
clf = Pipeline(
    steps=[("pre", ct),("clf", GradientBoostingClassifier())]
)
params={'pre__pca__n_components':[25,30,40],
        'clf__n_estimators':[80,100,150,200,250],
        'clf__learning_rate':[0.01,0.1],
        'clf__max_features': ['log2'],
        'clf__min_samples_split': [5,6,8,10]
        }
GS = GridSearchCV(clf,param_grid = params, scoring = ['roc_auc','balanced_accuracy'], n_jobs=-1, cv=5, refit=False)

# %%
GS.fit(x_train,y_train)
df_results = pd.DataFrame(GS.cv_results_)
df_results[['params','mean_test_roc_auc', 'std_test_roc_auc','mean_test_balanced_accuracy','std_test_balanced_accuracy']].sort_values(by='mean_test_roc_auc',ascending=False).head(10)
# Out:
#                                                 params  mean_test_roc_auc  \
# 70   {'clf__learning_rate': 0.1, 'clf__max_features...           0.985709
# 104  {'clf__learning_rate': 0.1, 'clf__max_features...           0.985378
# 87   {'clf__learning_rate': 0.1, 'clf__max_features...           0.985299
# 101  {'clf__learning_rate': 0.1, 'clf__max_features...           0.985139
# 118  {'clf__learning_rate': 0.1, 'clf__max_features...           0.985107
# 119  {'clf__learning_rate': 0.1, 'clf__max_features...           0.985053
# 73   {'clf__learning_rate': 0.1, 'clf__max_features...           0.985009
# 99   {'clf__learning_rate': 0.1, 'clf__max_features...           0.984859
# 72   {'clf__learning_rate': 0.1, 'clf__max_features...           0.984836
# 102  {'clf__learning_rate': 0.1, 'clf__max_features...           0.984826
#
#      std_test_roc_auc  mean_test_balanced_accuracy  std_test_balanced_accuracy
# 70           0.003534                     0.947539                    0.010069
# 104          0.003551                     0.944389                    0.004235
# 87           0.003075                     0.946246                    0.007967
# 101          0.003745                     0.944393                    0.009193
# 118          0.004313                     0.944027                    0.003516
# 119          0.004206                     0.943645                    0.007632
# 73           0.003820                     0.945329                    0.005624
# 99           0.004088                     0.946794                    0.008217
# 72           0.005048                     0.946449                    0.006241
# 102          0.003584                     0.944406                    0.008293

# %%
from sklearn import set_config
set_config(display="diagram")

# %%
clf
# Out:
# Pipeline(steps=[('pre',
#                  ColumnTransformer(transformers=[('scaler', StandardScaler(),
#                                                   ['word_freq_make',
#                                                    'word_freq_address',
#                                                    'word_freq_all',
#                                                    'word_freq_3d',
#                                                    'word_freq_our',
#                                                    'word_freq_over',
#                                                    'word_freq_remove',
#                                                    'word_freq_internet',
#                                                    'word_freq_order',
#                                                    'word_freq_mail',
#                                                    'word_freq_receive',
#                                                    'word_freq_will',
#                                                    'word_freq_people',
#                                                    'word_freq_report',
#                                                    'word_freq_addre...
#                                                    'word_freq_labs', ...]),
#                                                  ('pca2',
#                                                   PCA(n_components=3,
#                                                       random_state=42),
#                                                   ['char_freq_semicolon',
#                                                    'char_freq_bracket',
#                                                    'char_freq_sqbracket',
#                                                    'char_freq_excl',
#                                                    'char_freq_dollar',
#                                                    'char_freq_hash']),
#                                                  ('pca3',
#                                                   PCA(n_components=2,
#                                                       random_state=42),
#                                                   ['capital_run_length_average',
#                                                    'capital_run_length_longest',
#                                                    'capital_run_length_total'])])),
#                 ('clf', GradientBoostingClassifier())])

# %% [markdown]
# # PCA a todo

# %%
ct = ColumnTransformer([("scaler", StandardScaler(), columns_all),
                        ('pca',TruncatedSVD(n_iter=7, random_state=42),columns_freq)])

# %% [markdown]
# ## LR

# %%
clf = Pipeline(
    steps=[("pre", ct),("clf", LogisticRegression(max_iter=500))]
)
params={'pre__pca__n_components':[25,30,40],
        'clf__C':[0.01,0.1,1,10,80,100,300],
        'clf__penalty':['l1', 'l2'],
        'clf__class_weight':['balanced'],
        'clf__solver': ['liblinear'],
        }

GS = GridSearchCV(clf,param_grid = params, scoring = ['roc_auc','balanced_accuracy'], n_jobs=-1, cv=5, refit=False)

# %%
GS.fit(x_train,y_train)
df_results = pd.DataFrame(GS.cv_results_)
df_results[['params','mean_test_roc_auc', 'std_test_roc_auc','mean_test_balanced_accuracy','std_test_balanced_accuracy']].sort_values(by='mean_test_roc_auc',ascending=False).head(10)
# Out:
#                                                params  mean_test_roc_auc  \
# 15  {'clf__C': 1, 'clf__class_weight': 'balanced',...           0.968266
# 12  {'clf__C': 1, 'clf__class_weight': 'balanced',...           0.968256
# 16  {'clf__C': 1, 'clf__class_weight': 'balanced',...           0.968250
# 13  {'clf__C': 1, 'clf__class_weight': 'balanced',...           0.968243
# 17  {'clf__C': 1, 'clf__class_weight': 'balanced',...           0.968229
# 14  {'clf__C': 1, 'clf__class_weight': 'balanced',...           0.968223
# 11  {'clf__C': 0.1, 'clf__class_weight': 'balanced...           0.966639
# 9   {'clf__C': 0.1, 'clf__class_weight': 'balanced...           0.966611
# 10  {'clf__C': 0.1, 'clf__class_weight': 'balanced...           0.966582
# 21  {'clf__C': 10, 'clf__class_weight': 'balanced'...           0.966560
#
#     std_test_roc_auc  mean_test_balanced_accuracy  std_test_balanced_accuracy
# 15          0.005503                     0.920974                    0.009764
# 12          0.005187                     0.920056                    0.010094
# 16          0.005522                     0.920974                    0.009764
# 13          0.005193                     0.920056                    0.010094
# 17          0.005560                     0.920605                    0.010015
# 14          0.005204                     0.920056                    0.010094
# 11          0.003619                     0.915780                    0.007804
# 9           0.003640                     0.915780                    0.007601
# 10          0.003641                     0.915780                    0.007601
# 21          0.007139                     0.919142                    0.012411

# %% [markdown]
# ## SVM

# %%
clf = Pipeline(
    steps=[("pre", ct),("clf", SVC())]
)
params={'pre__pca__n_components':[25,30,40],
        'clf__C':[0.1,1,5,10,20,50,80],
        'clf__kernel':['rbf'],
        'clf__class_weight':['balanced'],
        'clf__gamma': ['auto','scale'],
        }
GS = GridSearchCV(clf,param_grid = params, scoring = ['roc_auc','balanced_accuracy'], n_jobs=-1, cv=5, refit=False)

# %%
GS.fit(x_train,y_train)
df_results = pd.DataFrame(GS.cv_results_)
df_results[['params','mean_test_roc_auc', 'std_test_roc_auc','mean_test_balanced_accuracy','std_test_balanced_accuracy']].sort_values(by='mean_test_roc_auc',ascending=False).head(10)
# Out:
#                                                params  mean_test_roc_auc  \
# 12  {'clf__C': 5, 'clf__class_weight': 'balanced',...           0.972467
# 14  {'clf__C': 5, 'clf__class_weight': 'balanced',...           0.972258
# 15  {'clf__C': 5, 'clf__class_weight': 'balanced',...           0.972254
# 16  {'clf__C': 5, 'clf__class_weight': 'balanced',...           0.972189
# 17  {'clf__C': 5, 'clf__class_weight': 'balanced',...           0.972172
# 13  {'clf__C': 5, 'clf__class_weight': 'balanced',...           0.972168
# 21  {'clf__C': 10, 'clf__class_weight': 'balanced'...           0.972099
# 20  {'clf__C': 10, 'clf__class_weight': 'balanced'...           0.972079
# 22  {'clf__C': 10, 'clf__class_weight': 'balanced'...           0.972022
# 23  {'clf__C': 10, 'clf__class_weight': 'balanced'...           0.971972
#
#     std_test_roc_auc  mean_test_balanced_accuracy  std_test_balanced_accuracy
# 12          0.010375                     0.926428                    0.007349
# 14          0.009893                     0.929033                    0.005750
# 15          0.010023                     0.928664                    0.006276
# 16          0.009837                     0.928296                    0.005688
# 17          0.009872                     0.928295                    0.005863
# 13          0.010057                     0.927355                    0.005827
# 21          0.010647                     0.924016                    0.007973
# 20          0.010504                     0.923647                    0.008304
# 22          0.010561                     0.923647                    0.008304
# 23          0.010507                     0.924015                    0.007930

# %% [markdown]
# ## RF

# %%
clf = Pipeline(
    steps=[("pre", ct),("clf", RandomForestClassifier())]
)

params={'pre__pca__n_components':[25,30,40],
        'clf__n_estimators':[50,100,150,200,250],
        'clf__class_weight':['balanced'],
        'clf__max_features': ['log2'],
        'clf__min_samples_split': [3,5,8,10,15]
        }
GS = GridSearchCV(clf,param_grid = params, scoring = ['roc_auc','balanced_accuracy'], n_jobs=-1, cv=5, refit=False)

# %%
GS.fit(x_train,y_train)
df_results = pd.DataFrame(GS.cv_results_)
df_results[['params','mean_test_roc_auc', 'std_test_roc_auc','mean_test_balanced_accuracy','std_test_balanced_accuracy']].sort_values(by='mean_test_roc_auc',ascending=False).head(10)
# Out:
#                                                params  mean_test_roc_auc  \
# 24  {'clf__class_weight': 'balanced', 'clf__max_fe...           0.983988
# 10  {'clf__class_weight': 'balanced', 'clf__max_fe...           0.983909
# 26  {'clf__class_weight': 'balanced', 'clf__max_fe...           0.983883
# 27  {'clf__class_weight': 'balanced', 'clf__max_fe...           0.983840
# 23  {'clf__class_weight': 'balanced', 'clf__max_fe...           0.983800
# 13  {'clf__class_weight': 'balanced', 'clf__max_fe...           0.983791
# 42  {'clf__class_weight': 'balanced', 'clf__max_fe...           0.983774
# 12  {'clf__class_weight': 'balanced', 'clf__max_fe...           0.983739
# 14  {'clf__class_weight': 'balanced', 'clf__max_fe...           0.983672
# 9   {'clf__class_weight': 'balanced', 'clf__max_fe...           0.983665
#
#     std_test_roc_auc  mean_test_balanced_accuracy  std_test_balanced_accuracy
# 24          0.002931                     0.939577                    0.010490
# 10          0.003216                     0.939184                    0.007703
# 26          0.003806                     0.939403                    0.009511
# 27          0.003326                     0.941426                    0.008478
# 23          0.003204                     0.939576                    0.010128
# 13          0.003267                     0.941985                    0.005337
# 42          0.002786                     0.943284                    0.012760
# 12          0.003273                     0.939397                    0.009921
# 14          0.003308                     0.939203                    0.006684
# 9           0.003074                     0.940328                    0.009266

# %%
clf.set_params(**	{'clf__class_weight': 'balanced', 'clf__max_features': 'log2', 'clf__min_samples_split': 3, 'clf__n_estimators': 250, 'pre__pca__n_components': 40})
clf.fit(x_train,y_train)

model_results = pd.DataFrame({"email_id": df_test.email_id, "predicted" : clf.predict_proba(x_test)[:,1]})
# model_results.to_csv("rf_standard_tifdf_pca_full.csv", index=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/pipeline.py:394: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)

# %% [markdown]
# ## GBM

# %%
clf = Pipeline(
    steps=[("pre", ct),("clf", GradientBoostingClassifier())]
)
params={'pre__pca__n_components':[25,30,40],
        'clf__n_estimators':[80,100,150,200,250],
        'clf__learning_rate':[0.01,0.1],
        'clf__max_features': ['log2'],
        'clf__min_samples_split': [5,6,8,10]
        }
GS = GridSearchCV(clf,param_grid = params, scoring = ['roc_auc','balanced_accuracy'], n_jobs=-1, cv=5, refit=False)

# %%
GS.fit(x_train,y_train)
df_results = pd.DataFrame(GS.cv_results_)
df_results[['params','mean_test_roc_auc', 'std_test_roc_auc','mean_test_balanced_accuracy','std_test_balanced_accuracy']].sort_values(by='mean_test_roc_auc',ascending=False).head(10)
# Out:
#                                                 params  mean_test_roc_auc  \
# 74   {'clf__learning_rate': 0.1, 'clf__max_features...           0.985315
# 119  {'clf__learning_rate': 0.1, 'clf__max_features...           0.985288
# 87   {'clf__learning_rate': 0.1, 'clf__max_features...           0.985170
# 118  {'clf__learning_rate': 0.1, 'clf__max_features...           0.985071
# 102  {'clf__learning_rate': 0.1, 'clf__max_features...           0.985059
# 70   {'clf__learning_rate': 0.1, 'clf__max_features...           0.985037
# 116  {'clf__learning_rate': 0.1, 'clf__max_features...           0.984948
# 104  {'clf__learning_rate': 0.1, 'clf__max_features...           0.984933
# 84   {'clf__learning_rate': 0.1, 'clf__max_features...           0.984837
# 99   {'clf__learning_rate': 0.1, 'clf__max_features...           0.984818
#
#      std_test_roc_auc  mean_test_balanced_accuracy  std_test_balanced_accuracy
# 74           0.004122                     0.944225                    0.006696
# 119          0.003003                     0.944035                    0.004437
# 87           0.004549                     0.945705                    0.006786
# 118          0.004892                     0.945331                    0.008620
# 102          0.004045                     0.948659                    0.007912
# 70           0.004019                     0.942182                    0.004402
# 116          0.004054                     0.945880                    0.011129
# 104          0.003640                     0.945328                    0.007416
# 84           0.004064                     0.942364                    0.004184
# 99           0.004941                     0.943476                    0.005987

# %% [markdown]
# # TF-IDF PCA

# %%
ct = ColumnTransformer([("scaler", StandardScaler(), columns_no_freq),
                        ('tfidf',TfidfTransformer(),columns_freq),
                        ('pca',TruncatedSVD(n_iter=7, random_state=42),columns_freq)])

# %% [markdown]
# ## LR

# %%
clf = Pipeline(
    steps=[("pre", ct),("clf", LogisticRegression(max_iter=500))]
)
params={'pre__pca__n_components':[40],
        'clf__C':[0.01,0.1,1,80,100],
        'clf__penalty':['l1', 'l2'],
        'clf__class_weight':['balanced'],
        'clf__solver': ['liblinear'],
        }

GS = GridSearchCV(clf,param_grid = params, scoring = ['roc_auc','balanced_accuracy'], n_jobs=-1, cv=5, refit=False)

# %%
GS.fit(x_train,y_train)
df_results = pd.DataFrame(GS.cv_results_) 
df_results[['params','mean_test_roc_auc', 'std_test_roc_auc','mean_test_balanced_accuracy','std_test_balanced_accuracy']].sort_values(by='mean_test_roc_auc',ascending=False).head(10)
# Out:
#                                               params  mean_test_roc_auc  \
# 5  {'clf__C': 1, 'clf__class_weight': 'balanced',...           0.971517
# 4  {'clf__C': 1, 'clf__class_weight': 'balanced',...           0.970256
# 7  {'clf__C': 80, 'clf__class_weight': 'balanced'...           0.968602
# 9  {'clf__C': 100, 'clf__class_weight': 'balanced...           0.968171
# 3  {'clf__C': 0.1, 'clf__class_weight': 'balanced...           0.967567
# 6  {'clf__C': 80, 'clf__class_weight': 'balanced'...           0.964879
# 8  {'clf__C': 100, 'clf__class_weight': 'balanced...           0.964689
# 2  {'clf__C': 0.1, 'clf__class_weight': 'balanced...           0.959843
# 1  {'clf__C': 0.01, 'clf__class_weight': 'balance...           0.959209
# 0  {'clf__C': 0.01, 'clf__class_weight': 'balance...           0.926680
#
#    std_test_roc_auc  mean_test_balanced_accuracy  std_test_balanced_accuracy
# 5          0.005692                     0.924139                    0.009491
# 4          0.006358                     0.921372                    0.010180
# 7          0.009014                     0.920982                    0.011330
# 9          0.009249                     0.920982                    0.011330
# 3          0.004070                     0.923777                    0.007915
# 6          0.011185                     0.919312                    0.012921
# 8          0.011286                     0.919312                    0.012921
# 2          0.005960                     0.914901                    0.008117
# 1          0.004811                     0.915143                    0.005451
# 0          0.013045                     0.854362                    0.015056

# %% [markdown]
# ## SVM

# %%
clf = Pipeline(
    steps=[("pre", ct),("clf", SVC())]
)
params={'pre__pca__n_components':[25,30,40],
        'clf__C':[0.1,1,5,10,20,50,80],
        'clf__kernel':['rbf'],
        'clf__class_weight':['balanced'],
        'clf__gamma': ['auto','scale'],
        }
GS = GridSearchCV(clf,param_grid = params, scoring = ['roc_auc','balanced_accuracy'], n_jobs=-1, cv=5, refit=False)

# %%
GS.fit(x_train,y_train)
df_results = pd.DataFrame(GS.cv_results_)
df_results[['params','mean_test_roc_auc', 'std_test_roc_auc','mean_test_balanced_accuracy','std_test_balanced_accuracy']].sort_values(by='mean_test_roc_auc',ascending=False).head(10)
# Out:
#                                                params  mean_test_roc_auc  \
# 17  {'clf__C': 5, 'clf__class_weight': 'balanced',...           0.974961
# 23  {'clf__C': 10, 'clf__class_weight': 'balanced'...           0.974198
# 15  {'clf__C': 5, 'clf__class_weight': 'balanced',...           0.974105
# 16  {'clf__C': 5, 'clf__class_weight': 'balanced',...           0.973715
# 21  {'clf__C': 10, 'clf__class_weight': 'balanced'...           0.973275
# 22  {'clf__C': 10, 'clf__class_weight': 'balanced'...           0.973247
# 11  {'clf__C': 1, 'clf__class_weight': 'balanced',...           0.973234
# 14  {'clf__C': 5, 'clf__class_weight': 'balanced',...           0.973083
# 20  {'clf__C': 10, 'clf__class_weight': 'balanced'...           0.972993
# 12  {'clf__C': 5, 'clf__class_weight': 'balanced',...           0.972707
#
#     std_test_roc_auc  mean_test_balanced_accuracy  std_test_balanced_accuracy
# 17          0.010233                     0.930355                    0.008097
# 23          0.010156                     0.929417                    0.005856
# 15          0.011683                     0.931270                    0.006981
# 16          0.011360                     0.930718                    0.007358
# 21          0.012118                     0.932013                    0.006672
# 22          0.011601                     0.929227                    0.005561
# 11          0.009020                     0.926471                    0.007185
# 14          0.010449                     0.929455                    0.009566
# 20          0.009925                     0.930378                    0.008175
# 12          0.011688                     0.928343                    0.006619

# %% [markdown]
# ## RF

# %%
ct = ColumnTransformer([("scaler", StandardScaler(), columns_no_freq),
                        ('tfidf',TfidfTransformer(),columns_freq),
                        ('pca',TruncatedSVD(n_iter=7, random_state=42),columns_freq)])

clf = Pipeline(
    steps=[("pre", ct),("clf", RandomForestClassifier())]
)

params={'pre__pca__n_components':[25,30,40],
        'clf__n_estimators':[100,150,200,250],
        'clf__class_weight':['balanced'],
        'clf__max_features': ['log2'],
        'clf__min_samples_split': [3,5,8,10,15]
        }
GS = GridSearchCV(clf,param_grid = params, scoring = ['roc_auc','balanced_accuracy'], n_jobs=-1, cv=5, refit=False)

# %%
GS.fit(x_train,y_train)
df_results = pd.DataFrame(GS.cv_results_)
df_results[['params','mean_test_roc_auc', 'std_test_roc_auc','mean_test_balanced_accuracy','std_test_balanced_accuracy']].sort_values(by='mean_test_roc_auc',ascending=False).head(10)
# Out:
#                                                params  mean_test_roc_auc  \
# 21  {'clf__class_weight': 'balanced', 'clf__max_fe...           0.984554
# 11  {'clf__class_weight': 'balanced', 'clf__max_fe...           0.984511
# 9   {'clf__class_weight': 'balanced', 'clf__max_fe...           0.984419
# 28  {'clf__class_weight': 'balanced', 'clf__max_fe...           0.984374
# 22  {'clf__class_weight': 'balanced', 'clf__max_fe...           0.984349
# 18  {'clf__class_weight': 'balanced', 'clf__max_fe...           0.984284
# 4   {'clf__class_weight': 'balanced', 'clf__max_fe...           0.984267
# 6   {'clf__class_weight': 'balanced', 'clf__max_fe...           0.984251
# 3   {'clf__class_weight': 'balanced', 'clf__max_fe...           0.984249
# 29  {'clf__class_weight': 'balanced', 'clf__max_fe...           0.984241
#
#     std_test_roc_auc  mean_test_balanced_accuracy  std_test_balanced_accuracy
# 21          0.003373                     0.939949                    0.008354
# 11          0.003820                     0.942541                    0.010320
# 9           0.003606                     0.945143                    0.007353
# 28          0.003588                     0.942555                    0.007542
# 22          0.003442                     0.939209                    0.009904
# 18          0.003717                     0.939581                    0.008393
# 4           0.002896                     0.939007                    0.005619
# 6           0.003835                     0.940505                    0.009596
# 3           0.003180                     0.942555                    0.011348
# 29          0.003612                     0.939575                    0.006585

# %%
clf.set_params(**	{'clf__class_weight': 'balanced', 'clf__max_features': 'log2', 'clf__min_samples_split': 5, 'clf__n_estimators': 250, 'pre__pca__n_components': 25})
clf.fit(x_train,y_train)

model_results = pd.DataFrame({"email_id": df_test.email_id, "predicted" : clf.predict_proba(x_test)[:,1]})
model_results.to_csv("rf_standard_tifdf_pca_full.csv", index=False)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/pipeline.py:394: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)

# %% [markdown]
# ## GBM

# %%
ct = ColumnTransformer([("scaler", StandardScaler(), columns_no_freq),
                        ('tfidf',TfidfTransformer(),columns_freq),
                        ('pca',TruncatedSVD(n_iter=7, random_state=42),columns_freq)])
clf = Pipeline(
    steps=[("pre", ct),("clf", GradientBoostingClassifier())]
)
params={'pre__pca__n_components':[25,30,40],
        'clf__n_estimators':[80,100,150,200,250],
        'clf__learning_rate':[0.01,0.1],
        'clf__max_features': ['log2'],
        'clf__min_samples_split': [5,6,8,10]
        }
GS = GridSearchCV(clf,param_grid = params, scoring = ['roc_auc','balanced_accuracy'], n_jobs=-1, cv=5, refit=False)

# %%
GS.fit(x_train,y_train)
df_results = pd.DataFrame(GS.cv_results_)
df_results[['params','mean_test_roc_auc', 'std_test_roc_auc','mean_test_balanced_accuracy','std_test_balanced_accuracy']].sort_values(by='mean_test_roc_auc',ascending=False).head(10)
# Out:
#                                                 params  mean_test_roc_auc  \
# 118  {'clf__learning_rate': 0.1, 'clf__max_features...           0.985580
# 71   {'clf__learning_rate': 0.1, 'clf__max_features...           0.985466
# 74   {'clf__learning_rate': 0.1, 'clf__max_features...           0.985204
# 117  {'clf__learning_rate': 0.1, 'clf__max_features...           0.985079
# 102  {'clf__learning_rate': 0.1, 'clf__max_features...           0.984918
# 101  {'clf__learning_rate': 0.1, 'clf__max_features...           0.984826
# 119  {'clf__learning_rate': 0.1, 'clf__max_features...           0.984808
# 68   {'clf__learning_rate': 0.1, 'clf__max_features...           0.984569
# 70   {'clf__learning_rate': 0.1, 'clf__max_features...           0.984569
# 103  {'clf__learning_rate': 0.1, 'clf__max_features...           0.984505
#
#      std_test_roc_auc  mean_test_balanced_accuracy  std_test_balanced_accuracy
# 118          0.004317                     0.944034                    0.007253
# 71           0.003077                     0.945888                    0.006639
# 74           0.003910                     0.946439                    0.007452
# 117          0.004543                     0.947924                    0.004294
# 102          0.004992                     0.946827                    0.010830
# 101          0.004093                     0.949047                    0.008171
# 119          0.004050                     0.944774                    0.008110
# 68           0.003926                     0.942555                    0.007211
# 70           0.003795                     0.943862                    0.011196
# 103          0.004301                     0.941448                    0.007203
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
clf.set_params(**{'clf__learning_rate': 0.1, 'clf__max_features': 'log2', 'clf__min_samples_split': 5, 'clf__n_estimators': 200, 'pre__pca__n_components': 40})
clf.fit(x_train,y_train)

model_results = pd.DataFrame({"email_id": df_test.email_id, "predicted" : clf.predict_proba(x_test)[:,1]})
model_results.to_csv("gbm_standard_tifdf_pca_full.csv", index=False)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# # Variance selection

# %%
selector = Pipeline(
    steps=[("preprocessor", MinMaxScaler((-1,1)))]
)
selector.fit(x_train)
# Out:
# Pipeline(steps=[('preprocessor', MinMaxScaler(feature_range=(-1, 1)))])

# %%
x_train
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 2257            0.00               0.00           0.00           0.0
# 2269            0.00               0.00           0.00           0.0
# 105             0.00               0.00           0.00           0.0
# 2309            0.00               0.00           0.20           0.0
# 1215            0.71               0.00           0.11           0.0
# ...              ...                ...            ...           ...
# 1987            0.05               0.05           0.40           0.0
# 1283            0.73               0.00           0.36           0.0
# 1414            0.25               0.00           0.51           0.0
# 1691            0.00               0.17           0.00           0.0
# 1867            0.00               0.00           0.52           0.0
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 2257           0.00            0.00              0.00                0.00
# 2269           0.00            0.00              0.00                0.00
# 105            0.51            0.00              0.00                0.00
# 2309           0.40            0.20              0.00                0.00
# 1215           0.47            0.11              0.00                0.59
# ...             ...             ...               ...                 ...
# 1987           0.34            0.00              0.00                0.00
# 1283           0.36            0.36              1.10                0.00
# 1414           0.25            1.28              0.00                0.00
# 1691           0.00            0.00              0.17                0.17
# 1867           0.00            1.05              0.52                0.00
#
#       word_freq_order  word_freq_mail  ...  word_freq_conference  \
# 2257             0.00            1.01  ...                   0.0
# 2269             1.81            0.00  ...                   0.0
# 105              0.00            0.00  ...                   0.0
# 2309             0.00            0.00  ...                   0.0
# 1215             0.71            2.86  ...                   0.0
# ...               ...             ...  ...                   ...
# 1987             0.57            0.05  ...                   0.0
# 1283             0.00            0.00  ...                   0.0
# 1414             0.77            0.51  ...                   0.0
# 1691             0.00            0.17  ...                   0.0
# 1867             0.00            0.00  ...                   0.0
#
#       char_freq_semicolon  char_freq_bracket  char_freq_sqbracket  \
# 2257                0.000              0.000                0.312
# 2269                0.000              0.316                0.000
# 105                 0.000              0.000                0.000
# 2309                0.000              0.000                0.000
# 1215                0.072              0.127                0.000
# ...                   ...                ...                  ...
# 1987                0.019              0.099                0.000
# 1283                0.000              0.186                0.000
# 1414                0.000              0.086                0.000
# 1691                0.108              0.216                0.061
# 1867                0.000              0.194                0.000
#
#       char_freq_excl  char_freq_dollar  char_freq_hash  \
# 2257           0.000             0.000           0.000
# 2269           0.000             0.000           0.000
# 105            0.281             0.000           0.000
# 2309           0.382             0.223           0.478
# 1215           0.418             0.254           0.018
# ...              ...               ...             ...
# 1987           0.099             0.079           0.009
# 1283           0.435             0.062           0.000
# 1414           0.260             0.173           0.000
# 1691           0.046             0.030           0.000
# 1867           0.291             0.000           0.000
#
#       capital_run_length_average  capital_run_length_longest  \
# 2257                       4.030                          28
# 2269                       1.125                           2
# 105                        1.363                           5
# 2309                       7.538                          55
# 1215                       9.705                         148
# ...                          ...                         ...
# 1987                       4.881                          95
# 1283                       4.411                         190
# 1414                       3.298                          16
# 1691                       4.259                          85
# 1867                       3.333                          43
#
#       capital_run_length_total
# 2257                       133
# 2269                         9
# 105                         45
# 2309                       490
# 1215                      1514
# ...                        ...
# 1987                      1313
# 1283                       300
# 1414                       287
# 1691                      3318
# 1867                       120
#
# [2254 rows x 57 columns]

# %%
np.percentile(np.var(selector.transform(x_train),axis=0),q=[25,50,75])
# Out:
# array([0.00552808, 0.01183875, 0.024645  ])

# %%
clf = Pipeline(
    steps=[("preprocessor", MinMaxScaler((-1,1))), ('selector', VarianceThreshold()), ("clf", RandomForestClassifier())]
)

# %%
params={'selector__threshold':[0.0118,0.0055],
        'clf__n_estimators':[80,100,150,200,250],
        'clf__class_weight':['balanced'],
        'clf__max_features': ['log2'],
        'clf__min_samples_split': [3,5,6,8,10]
        }
GS = GridSearchCV(clf,param_grid = params, scoring = 'roc_auc', n_jobs=-1, cv=5)

# %%
GS.fit(x_train,y_train)
df_results = pd.DataFrame(GS.cv_results_)
df_results[['params','mean_test_score','std_test_score']].sort_values(by='mean_test_score',ascending=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/pipeline.py:394: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#                                                params  mean_test_score  \
# 27  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.981846
# 29  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.981537
# 19  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.981320
# 15  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.981279
# 39  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.981270
# 23  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.981263
# 45  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.981246
# 7   {'clf__class_weight': 'balanced', 'clf__max_fe...         0.981204
# 21  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.981158
# 17  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.981148
# 47  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.981125
# 33  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.981006
# 37  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.980973
# 9   {'clf__class_weight': 'balanced', 'clf__max_fe...         0.980840
# 43  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.980826
# 35  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.980816
# 1   {'clf__class_weight': 'balanced', 'clf__max_fe...         0.980789
# 13  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.980769
# 49  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.980695
# 25  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.980656
# 3   {'clf__class_weight': 'balanced', 'clf__max_fe...         0.980378
# 11  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.980328
# 31  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.980226
# 5   {'clf__class_weight': 'balanced', 'clf__max_fe...         0.980090
# 41  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.979837
# 38  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.962576
# 36  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.962506
# 42  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.961926
# 24  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.961667
# 48  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.961597
# 28  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.961570
# 44  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.961455
# 46  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.961312
# 40  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.961299
# 26  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.961235
# 18  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.961028
# 14  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.960899
# 16  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.960755
# 34  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.960563
# 30  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.960352
# 10  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.960287
# 8   {'clf__class_weight': 'balanced', 'clf__max_fe...         0.960203
# 22  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.960088
# 32  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.960083
# 6   {'clf__class_weight': 'balanced', 'clf__max_fe...         0.960040
# 20  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.959948
# 12  {'clf__class_weight': 'balanced', 'clf__max_fe...         0.959729
# 4   {'clf__class_weight': 'balanced', 'clf__max_fe...         0.959460
# 0   {'clf__class_weight': 'balanced', 'clf__max_fe...         0.959244
# 2   {'clf__class_weight': 'balanced', 'clf__max_fe...         0.958462
#
#     std_test_score
# 27        0.004880
# 29        0.004692
# 19        0.004781
# 15        0.004354
# 39        0.004501
# 23        0.005040
# 45        0.004471
# 7         0.005038
# 21        0.004949
# 17        0.004616
# 47        0.004855
# 33        0.005017
# 37        0.005233
# 9         0.004936
# 43        0.005282
# 35        0.004470
# 1         0.005302
# 13        0.004891
# 49        0.004760
# 25        0.004277
# 3         0.004564
# 11        0.004652
# 31        0.005103
# 5         0.004349
# 41        0.005046
# 38        0.011051
# 36        0.011573
# 42        0.011233
# 24        0.011342
# 48        0.010426
# 28        0.010373
# 44        0.011597
# 46        0.011001
# 40        0.011810
# 26        0.011166
# 18        0.011613
# 14        0.011654
# 16        0.011161
# 34        0.010923
# 30        0.011340
# 10        0.011839
# 8         0.011731
# 22        0.011648
# 32        0.009810
# 6         0.011710
# 20        0.010590
# 12        0.011435
# 4         0.011763
# 0         0.012163
# 2         0.011989
